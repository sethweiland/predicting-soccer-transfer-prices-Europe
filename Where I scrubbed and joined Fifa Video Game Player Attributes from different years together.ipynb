# %%
import sqlite3
import pandas as pd
import feather
from multiprocessing import Pool

# %%
conn = sqlite3.connect("database.sqlite")

# %%
df = pd.read_sql_query("SELECT * FROM Player_Attributes LIMIT 10",conn)

# %%
df.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00              67
# 1   2              218353         505942  2015-11-19 00:00:00              67
# 2   3              218353         505942  2015-09-21 00:00:00              62
# 3   4              218353         505942  2015-03-20 00:00:00              61
# 4   5              218353         505942  2007-02-22 00:00:00              61
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0         71          right              medium              medium        49
# 1         71          right              medium              medium        49
# 2         66          right              medium              medium        49
# 3         65          right              medium              medium        48
# 4         65          right              medium              medium        48
#
# ...

# %%
df_2016 = pd.read_sql_query("SELECT * FROM Player_Attributes",conn)

# %%
df_2016.shape
# Out:
# (183978, 42)

# %%
df_2016['DATETIME'] = pd.to_datetime(df_2016['date'])

# %%
df_2016.shape
# Out:
# (183978, 43)

# %%
df_2016.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
df_2016 = df_2016.loc[df_2016['DATETIME'].dt.year==2016]

# %%
df_2016.tail(35)
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 183513  183514              195090         157284  2016-01-21 00:00:00
# 183571  183572              206209         290868  2016-04-21 00:00:00
# 183572  183573              206209         290868  2016-01-14 00:00:00
# 183589  183590              207780         169594  2016-02-11 00:00:00
# 183607  183608              223263         244953  2016-05-05 00:00:00
# 183608  183609              223263         244953  2016-03-10 00:00:00
# 183625  183626              228821         642618  2016-04-21 00:00:00
# 183626  183627              228821         642618  2016-04-07 00:00:00
# 183627  183628              228821         642618  2016-01-28 00:00:00
# 183628  183629              228821         642618  2016-01-21 00:00:00
# 183634  183635              204227         277772  2016-04-28 00:00:00
# 183635  183636              204227         277772  2016-03-24 00:00:00
# ...

# %%
player_names = pd.read_sql_query("SELECT p.*,PA.* FROM Player p INNER JOIN Player_Attributes PA ON p.player_fifa_api_id=PA.player_fifa_api_id",conn)

# %%
player_names['DATETIME'] = pd.to_datetime(player_names['date'])

# %%
player_names['DATETIME'].dtype
# Out:
# dtype('<M8[ns]')

# %%
player_names = player_names.loc[player_names['DATETIME'].dt.year==2016]

# %%
player_names.columns
# Out:
# Index(['id', 'player_api_id', 'player_name', 'player_fifa_api_id', 'birthday',
#        'height', 'weight', 'id', 'player_fifa_api_id', 'player_api_id', 'date',
#        'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes', 'DATETIME'],
#       dtype='object')

# %%
player_names[player_names['player_name'].str.contains("Aguero")]['overall_rating']
# Out:
# 160786    88.0
# 160787    88.0
# 160788    88.0
# Name: overall_rating, dtype: float64

# %%
columns_keep = ["player_name", "overall_rating","sprint_speed", "agility","jumping","strength","standing_tackle", "sliding_tackle"]

# %%
player_names.head()
# Out:
#     id  player_api_id         player_name  player_fifa_api_id  \
# 0    1         505942  Aaron Appindangoye              218353
# 5    2         155782     Aaron Cresswell              189615
# 6    2         155782     Aaron Cresswell              189615
# 7    2         155782     Aaron Cresswell              189615
# 38   3         162549         Aaron Doran              186170
#
#                birthday  height  weight  id  player_fifa_api_id  \
# 0   1992-02-29 00:00:00  182.88     187   1              218353
# 5   1989-12-15 00:00:00  170.18     146   6              189615
# 6   1989-12-15 00:00:00  170.18     146   7              189615
# 7   1989-12-15 00:00:00  170.18     146   8              189615
# 38  1991-05-13 00:00:00  170.18     163  39              186170
#
#     player_api_id  ... penalties  marking  standing_tackle sliding_tackle  \
# 0          505942  ...      48.0     65.0             69.0           69.0
# ...

# %%
player_names_keep = player_names[columns_keep]

# %%
df_16_keep = player_names_keep

# %%
df_16_keep.head()
# Out:
#            player_name  overall_rating  sprint_speed  agility  jumping  \
# 0   Aaron Appindangoye            67.0          64.0     59.0     58.0
# 5      Aaron Cresswell            74.0          78.0     78.0     85.0
# 6      Aaron Cresswell            74.0          78.0     78.0     85.0
# 7      Aaron Cresswell            73.0          78.0     78.0     84.0
# 38         Aaron Doran            65.0          74.0     85.0     65.0
#
#     strength  standing_tackle  sliding_tackle
# 0       76.0             69.0            69.0
# 5       56.0             75.0            78.0
# 6       56.0             75.0            78.0
# 7       56.0             75.0            78.0
# 38      71.0             22.0            24.0

# %%
df_16_keep['season'] = "2015-16"
# Out:
# /Users/sethweiland/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_16_keep.shape
# Out:
# (14098, 9)

# %%
df_18 = pd.read_csv("fifa_18/FullData.csv")
# Out:
# /Users/sethweiland/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_18.shape
# Out:
# (17981, 75)

# %%
df_18.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions',
#        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID',
#        'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB',
#        'Preferred Positions', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM',
#        'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
df_18_keep = df_18[['Name', "Overall", "Sprint speed", "Agility","Jumping","Strength", "Standing tackle", "Sliding tackle"]]

# %%
df_18_keep['season'] = "2017-18"
# Out:
# /Users/sethweiland/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_18_keep.shape
# Out:
# (17981, 9)

# %%
df_19 = pd.read_csv("fifa_19/FullData.csv")

# %%
df_19.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df_19_keep = df_19[["Name", "Overall", "SprintSpeed", "Agility","Jumping", "Strength", "StandingTackle", "SlidingTackle"]]

# %%
df_19_keep['season'] = "2018-19"
# Out:
# /Users/sethweiland/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_19_keep.shape
# Out:
# (18207, 9)

# %%
df_17 = pd.read_csv("fifa_17/FullData.csv")

# %%
df_17.shape
# Out:
# (17588, 53)

# %%
df_17.columns
# Out:
# Index(['Name', 'Nationality', 'National_Position', 'National_Kit', 'Club',
#        'Club_Position', 'Club_Kit', 'Club_Joining', 'Contract_Expiry',
#        'Rating', 'Height', 'Weight', 'Preffered_Foot', 'Birth_Date', 'Age',
#        'Preffered_Position', 'Work_Rate', 'Weak_foot', 'Skill_Moves',
#        'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
#        'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
#        'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
#        'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
#        'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
#        'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
#        'GK_Reflexes'],
#       dtype='object')

# %%
df_17_keep = df_17[['Name', "Rating", "Speed", "Agility","Jumping","Strength", "Standing_Tackle", "Sliding_Tackle"]]

# %%
df_17_keep['season'] = "2016-17"
# Out:
# /Users/sethweiland/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_17_keep.columns
# Out:
# Index(['Name', 'Rating', 'Speed', 'Agility', 'Jumping', 'Strength',
#        'Standing_Tackle', 'Sliding_Tackle', 'season'],
#       dtype='object')

# %%
df_16_keep.columns = df_17_keep.columns

# %%
df_18_keep.columns = df_17_keep.columns

# %%
df_19_keep.columns = df_17_keep.columns

# %%
df_list_fifas = [df_16_keep, df_17_keep,df_18_keep,df_19_keep]

# %%
df_total = pd.concat(df_list_fifas)

# %%
df_total.columns
# Out:
# Index(['Name', 'Rating', 'Speed', 'Agility', 'Jumping', 'Strength',
#        'Standing_Tackle', 'Sliding_Tackle', 'season'],
#       dtype='object')

# %%
df_total.shape
# Out:
# (67874, 9)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67874 entries, 0 to 18206
# Data columns (total 9 columns):
# Name               67874 non-null object
# Rating             67874 non-null float64
# Speed              67826 non-null object
# Agility            67826 non-null object
# Jumping            67826 non-null object
# Strength           67826 non-null object
# Standing_Tackle    67826 non-null object
# Sliding_Tackle     67826 non-null object
# season             67874 non-null object
# dtypes: float64(1), object(8)
# memory usage: 5.2+ MB

# %%
convert_numeric = ['Rating',"Speed", "Agility","Jumping","Strength", "Standing_Tackle", "Sliding_Tackle"]

# %%
df_total[convert_numeric] = df_total[convert_numeric].apply(pd.to_numeric,errors = "coerce")

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67874 entries, 0 to 18206
# Data columns (total 9 columns):
# Name               67874 non-null object
# Rating             67874 non-null float64
# Speed              67712 non-null float64
# Agility            67755 non-null float64
# Jumping            67756 non-null float64
# Strength           67722 non-null float64
# Standing_Tackle    67702 non-null float64
# Sliding_Tackle     67731 non-null float64
# season             67874 non-null object
# dtypes: float64(7), object(2)
# memory usage: 5.2+ MB

# %%
df_total.dropna(inplace=True)

# %%
df_total.shape
# Out:
# (67499, 9)

# %%
df_total.drop_duplicates(inplace=True)

# %%
df_total.shape
# Out:
# (62366, 9)

# %%
feather.write_dataframe(df_total, "fifa_df.feather")

# %% [markdown]
# ## This feathered dataframe will be revisited and merged with the main dataset that has our target feature "fee_cleaned" i.e. player acquisition price
